# %% [markdown]
# <a href="https://colab.research.google.com/github/Queen-Rukky/Analysis-of-Consumer-Preferences-in-Beauty-and-Cosmetics-Products/blob/main/Crash_Report_Driverd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df= pd.read_csv('/content/Crash_Reporting_-_Drivers_Data (2).csv')

# %%
df
# Out:
#     Report Number  Local Case Number                Agency Name  \
# 0     MCP209400N4          230072733   Montgomery County Police
# 1      DD5660000Q          230068281  Rockville Police Departme
# 2      EJ78870037          230062614  Gaithersburg Police Depar
# 3      DD559500FC          230066545  Rockville Police Departme
# 4     MCP23390086          230022456   Montgomery County Police
# ..            ...                ...                        ...
# 549    EJ7833008J          240057696               GAITHERSBURG
# 550    DD5612006C          240056270                  ROCKVILLE
# 551   MCP3111008R          240057181                 MONTGOMERY
# 552   MCP3307002J          240057299                 MONTGOMERY
# 553   MCP33720036          240057814                 MONTGOMERY
#
#           ACRS Report Type  Crash Date              Route Type  \
# 0             Injury Crash  12/20/2023        Maryland (State)
# 1             Injury Crash  11/26/2023        Maryland (State)
# ...

# %% [markdown]
# df.shape()

# %%
df.shape
# Out:
# (554, 36)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Report Number  Local Case Number                Agency Name  \
# 0     MCP209400N4          230072733   Montgomery County Police
# 1      DD5660000Q          230068281  Rockville Police Departme
# 2      EJ78870037          230062614  Gaithersburg Police Depar
# 3      DD559500FC          230066545  Rockville Police Departme
# 4     MCP23390086          230022456   Montgomery County Police
# ..            ...                ...                        ...
# 549    EJ7833008J          240057696               GAITHERSBURG
# 550    DD5612006C          240056270                  ROCKVILLE
# 551   MCP3111008R          240057181                 MONTGOMERY
# 552   MCP3307002J          240057299                 MONTGOMERY
# 553   MCP33720036          240057814                 MONTGOMERY
#
#           ACRS Report Type  Crash Date              Route Type  \
# 0             Injury Crash  12/20/2023        Maryland (State)
# ...

# %%
df.columns
# Out:
# Index(['Report Number', 'Local Case Number', 'Agency Name', 'ACRS Report Type',
#        'Crash Date', 'Route Type', 'Road Name', 'Cross-Street Name',
#        'Municipality', 'Related Non-Motorist', 'Collision Type', 'Weather',
#        'Surface Condition', 'Light', 'Traffic Control',
#        'Driver Substance Abuse', 'Non-Motorist Substance Abuse', 'Person ID',
#        'Driver At Fault', 'Injury Severity', 'Circumstance',
#        'Driver Distracted By', 'Drivers License State', 'Vehicle ID',
#        'Vehicle Damage Extent', 'Vehicle First Impact Location',
#        'Vehicle Body Type', 'Vehicle Movement', 'Vehicle Going Dir',
#        'Speed Limit', 'Vehicle Year', 'Vehicle Make', 'Vehicle Model',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df1= df.drop_duplicates()

# %%
df1
# Out:
#     Report Number  Local Case Number                Agency Name  \
# 0     MCP209400N4          230072733   Montgomery County Police
# 1      DD5660000Q          230068281  Rockville Police Departme
# 2      EJ78870037          230062614  Gaithersburg Police Depar
# 3      DD559500FC          230066545  Rockville Police Departme
# 4     MCP23390086          230022456   Montgomery County Police
# ..            ...                ...                        ...
# 549    EJ7833008J          240057696               GAITHERSBURG
# 550    DD5612006C          240056270                  ROCKVILLE
# 551   MCP3111008R          240057181                 MONTGOMERY
# 552   MCP3307002J          240057299                 MONTGOMERY
# 553   MCP33720036          240057814                 MONTGOMERY
#
#           ACRS Report Type  Crash Date              Route Type  \
# 0             Injury Crash  12/20/2023        Maryland (State)
# 1             Injury Crash  11/26/2023        Maryland (State)
# ...

# %%
df1.isnull().any()
# Out:
# Report Number                    False
# Local Case Number                False
# Agency Name                      False
# ACRS Report Type                 False
# Crash Date                       False
# Route Type                       False
# Road Name                        False
# Cross-Street Name                False
# Municipality                      True
# Related Non-Motorist             False
# Collision Type                   False
# Weather                          False
# Surface Condition                False
# Light                            False
# Traffic Control                  False
# Driver Substance Abuse           False
# Non-Motorist Substance Abuse      True
# Person ID                        False
# Driver At Fault                  False
# Injury Severity                   True
# Circumstance                      True
# Driver Distracted By              True
# Drivers License State             True
# Vehicle ID                       False
# ...

# %%
df.shape
# Out:
# (554, 36)

# %%
df1=df.drop(columns = ['Municipality','Non-Motorist Substance Abuse' ], axis = 0)
df1
# Out:
#     Report Number  Local Case Number                Agency Name  \
# 0     MCP209400N4          230072733   Montgomery County Police
# 1      DD5660000Q          230068281  Rockville Police Departme
# 2      EJ78870037          230062614  Gaithersburg Police Depar
# 3      DD559500FC          230066545  Rockville Police Departme
# 4     MCP23390086          230022456   Montgomery County Police
# ..            ...                ...                        ...
# 549    EJ7833008J          240057696               GAITHERSBURG
# 550    DD5612006C          240056270                  ROCKVILLE
# 551   MCP3111008R          240057181                 MONTGOMERY
# 552   MCP3307002J          240057299                 MONTGOMERY
# 553   MCP33720036          240057814                 MONTGOMERY
#
#           ACRS Report Type  Crash Date              Route Type  \
# 0             Injury Crash  12/20/2023        Maryland (State)
# 1             Injury Crash  11/26/2023        Maryland (State)
# ...

# %%
df1.describe()
# Out:
#        Local Case Number  Speed Limit  Vehicle Year    Latitude   Longitude
# count       5.540000e+02   554.000000    554.000000  554.000000  554.000000
# mean        1.814776e+08    29.494585   1954.485560   39.077421  -77.134700
# std         8.093156e+07     7.625797    337.415623    0.056758    0.073907
# min         1.500874e+07     0.000000      0.000000   38.952128  -77.412642
# 25%         1.800210e+08    25.000000   2008.000000   39.051336  -77.186780
# 50%         2.200056e+08    30.000000   2013.000000   39.083436  -77.143335
# 75%         2.400182e+08    35.000000   2017.000000   39.118738  -77.092996
# max         2.400578e+08    50.000000   2024.000000   39.275468  -76.923370

# %%
df.plot()
# Out:
# <Axes: >

# %%
df1['Speed Limit'].mean()
# Out:
# 29.494584837545126

# %%
df = df['Local Case Number'].sum()
df
# Out:
# 100538571777

# %%
df1['ACRS Report Type'].head(10)
# Out:
# 0             Injury Crash
# 1             Injury Crash
# 2    Property Damage Crash
# 3             Injury Crash
# 4             Injury Crash
# 5             Injury Crash
# 6             Injury Crash
# 7             Injury Crash
# 8             Injury Crash
# 9             Injury Crash
# Name: ACRS Report Type, dtype: object

# %%
df1. groupby('ACRS Report Type')['Local Case Number'].mean()
# Out:
# ACRS Report Type
# Fatal Crash              2.139563e+08
# Injury Crash             1.800509e+08
# Property Damage Crash    1.837262e+08
# Name: Local Case Number, dtype: float64

# %%
df1. groupby('ACRS Report Type')['Local Case Number'].max()
# Out:
# ACRS Report Type
# Fatal Crash              240047962
# Injury Crash             240057814
# Property Damage Crash    240049380
# Name: Local Case Number, dtype: int64

# %%
df1
# Out:
#     Report Number  Local Case Number                Agency Name  \
# 0     MCP209400N4          230072733   Montgomery County Police
# 1      DD5660000Q          230068281  Rockville Police Departme
# 2      EJ78870037          230062614  Gaithersburg Police Depar
# 3      DD559500FC          230066545  Rockville Police Departme
# 4     MCP23390086          230022456   Montgomery County Police
# ..            ...                ...                        ...
# 549    EJ7833008J          240057696               GAITHERSBURG
# 550    DD5612006C          240056270                  ROCKVILLE
# 551   MCP3111008R          240057181                 MONTGOMERY
# 552   MCP3307002J          240057299                 MONTGOMERY
# 553   MCP33720036          240057814                 MONTGOMERY
#
#           ACRS Report Type  Crash Date              Route Type  \
# 0             Injury Crash  12/20/2023        Maryland (State)
# 1             Injury Crash  11/26/2023        Maryland (State)
# ...

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.boxplot(figsize = ( 20, 10))
# Out:
# <Axes: >

# %%
df1.select_dtypes(include = 'number')
# Out:
#      Local Case Number  Speed Limit  Vehicle Year   Latitude  Longitude
# 0            230072733           25          2017  39.027575 -77.077805
# 1            230068281           35          2021  39.059047 -77.121795
# 2            230062614           25          2018  39.140472 -77.224669
# 3            230066545           40          2019  39.062021 -77.124050
# 4            230022456           35          2018  39.096694 -77.135390
# ..                 ...          ...           ...        ...        ...
# 549          240057696           25             0  39.125972 -77.182899
# 550          240056270           25          2023  39.060109 -77.120206
# 551          240057181           25          2021  38.982225 -77.093276
# 552          240057299           40          2009  39.112430 -77.059021
# 553          240057814           25          2020  39.074879 -77.083423
#
# [554 rows x 5 columns]

# %%
dfi= df1[['Crash Date','Local Case Number']]
dfi
# Out:
#      Crash Date  Local Case Number
# 0    12/20/2023          230072733
# 1    11/26/2023          230068281
# 2     11/7/2023          230062614
# 3    11/15/2023          230066545
# 4     5/10/2023          230022456
# ..          ...                ...
# 549   12/2/2024          240057696
# 550  11/23/2024          240056270
# 551  11/29/2024          240057181
# 552  11/30/2024          240057299
# 553   12/3/2024          240057814
#
# [554 rows x 2 columns]

# %%
# @title Local Case Number

from matplotlib import pyplot as plt
dfi['Local Case Number'].plot(kind='hist', bins=20, title='Local Case Number')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Local Case Number

from matplotlib import pyplot as plt
dfi['Local Case Number'].plot(kind='hist', bins=20, title='Local Case Number')
plt.gca().spines[['top', 'right',]].set_visible(False)
