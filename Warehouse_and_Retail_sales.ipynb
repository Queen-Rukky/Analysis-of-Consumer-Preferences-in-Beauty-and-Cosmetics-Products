# %% [markdown]
# <a href="https://colab.research.google.com/github/Queen-Rukky/Analysis-of-Consumer-Preferences-in-Beauty-and-Cosmetics-Products/blob/main/Warehouse_and_Retail_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Warehouse_and_Retail_Sales (1).csv')
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
# 82673  2017      9              YOUNG WON TRADING INC    377120
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82674 entries, 0 to 82673
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              82674 non-null  int64
#  1   MONTH             82674 non-null  int64
#  2   SUPPLIER          82630 non-null  object
#  3   ITEM CODE         82674 non-null  object
#  4   ITEM DESCRIPTION  82674 non-null  object
#  5   ITEM TYPE         82674 non-null  object
#  6   RETAIL SALES      82672 non-null  float64
#  7   RETAIL TRANSFERS  82673 non-null  float64
#  8   WAREHOUSE SALES   82673 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 5.7+ MB

# %%
df.shape
# Out:
# (82674, 9)

# %%
df.isnull().sum()
# Out:
# YEAR                 0
# MONTH                0
# SUPPLIER            44
# ITEM CODE            0
# ITEM DESCRIPTION     0
# ITEM TYPE            0
# RETAIL SALES         2
# RETAIL TRANSFERS     1
# WAREHOUSE SALES      1
# dtype: int64

# %%
df=df.drop_duplicates()
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
# 82673  2017      9              YOUNG WON TRADING INC    377120
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.tail(10)
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 82664  2017      9  REPUBLIC NATIONAL DISTRIBUTING CO    376469
# 82665  2017      9               DIONYSOS IMPORTS INC     37648
# 82666  2017      9                 BARON FRANCOIS LTD    376485
# 82667  2017      9              A VINTNERS SELECTIONS    376523
# 82668  2017      9                KOBRAND CORPORATION    376655
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
# 82673  2017      9              YOUNG WON TRADING INC    377120
#
#                            ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 82664              BISANZIO MONTEPUL - 1.5L      WINE          0.34
# 82665               MONTE VELHO RED - 750ML      WINE          1.00
# ...

# %%
df= df.dropna()
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82668  2017      9                KOBRAND CORPORATION    376655
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.describe()
# Out:
#                YEAR         MONTH  RETAIL SALES  RETAIL TRANSFERS  \
# count  82629.000000  82629.000000  82629.000000      82629.000000
# mean    2018.267110      5.760617      7.065788          6.934917
# std        1.481819      2.572949     31.250485         31.124134
# min     2017.000000      1.000000     -6.490000        -38.490000
# 25%     2017.000000      3.000000      0.000000          0.000000
# 50%     2017.000000      7.000000      0.240000          0.000000
# 75%     2020.000000      8.000000      3.220000          3.000000
# max     2020.000000     12.000000   1816.490000       1990.830000
#
#        WAREHOUSE SALES
# count     82629.000000
# mean         26.918579
# std         270.229677
# min       -4804.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82668  2017      9                KOBRAND CORPORATION    376655
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.groupby('YEAR').agg({'RETAIL SALES':['mean','max','min','count']})
# Out:
#      RETAIL SALES
#              mean      max   min  count
# YEAR
# 2017     6.466697  1364.00 -6.49  47729
# 2020     7.885100  1816.49 -0.42  34900

# %%
df.groupby('YEAR').agg({'RETAIL TRANSFERS':['mean','max','min','count']})
# Out:
#      RETAIL TRANSFERS
#                  mean      max    min  count
# YEAR
# 2017         6.348762  1186.00 -38.49  47729
# 2020         7.736537  1990.83  -6.00  34900

# %%
df.groupby('YEAR').agg({'WAREHOUSE SALES':['mean','max','min','count']})
# Out:
#      WAREHOUSE SALES
#                 mean       max     min  count
# YEAR
# 2017       25.076649  15955.46 -4804.0  47729
# 2020       29.437589  18317.00 -3999.0  34900

# %%
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82668  2017      9                KOBRAND CORPORATION    376655
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.plot(kind='line',title ='Sales Vs Date',xlabel ='YEAR',ylabel ='WAREHOUSE SALES' )
# Out:
# <Axes: title={'center': 'Sales Vs Date'}, xlabel='YEAR', ylabel='WAREHOUSE SALES'>

# %%
df.select_dtypes(include = 'number')
# Out:
#        YEAR  MONTH  RETAIL SALES  RETAIL TRANSFERS  WAREHOUSE SALES
# 0      2020      1          0.00               0.0              2.0
# 1      2020      1          0.00               1.0              4.0
# 2      2020      1          0.00               0.0              1.0
# 3      2020      1          0.00               0.0              1.0
# 4      2020      1          0.82               0.0              0.0
# ...     ...    ...           ...               ...              ...
# 82668  2017      9          0.08               0.0              0.0
# 82669  2017      9          0.00               0.0              7.0
# 82670  2017      9          0.00               0.0              2.0
# 82671  2017      9          0.00               0.0              8.0
# 82672  2017      9          0.21               0.0              2.0
#
# [82629 rows x 5 columns]

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df
# Out:
#        YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0      2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1      2020      1                          PWSWN INC    100024
# 2      2020      1            RELIABLE CHURCHILL LLLP      1001
# 3      2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4      2020      1               DIONYSOS IMPORTS INC    100293
# ...     ...    ...                                ...       ...
# 82668  2017      9                KOBRAND CORPORATION    376655
# 82669  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376930
# 82670  2017      9  SOUTHERN GLAZERS WINE AND SPIRITS    376949
# 82671  2017      9              A VINTNERS SELECTIONS    377082
# 82672  2017      9              YOUNG WON TRADING INC    377112
#
#                           ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                      BOOTLEG RED - 750ML      WINE          0.00
# ...

# %%
df.plot(x="YEAR", y=["WAREHOUSE SALES", "ITEM TYPE"],kind="line", figsize=(10, 6))
# Display plot
plt.show()

# %%
selected_columns = df.iloc[:, [0, 5, 8]]
selected_columns
# Out:
#        YEAR ITEM TYPE  WAREHOUSE SALES
# 0      2020      WINE              2.0
# 1      2020      WINE              4.0
# 2      2020      BEER              1.0
# 3      2020      WINE              1.0
# 4      2020      WINE              0.0
# ...     ...       ...              ...
# 82668  2017      WINE              0.0
# 82669  2017      WINE              7.0
# 82670  2017      WINE              2.0
# 82671  2017      WINE              8.0
# 82672  2017      WINE              2.0
#
# [82629 rows x 3 columns]

# %%
df.plot.scatter(x= 'WAREHOUSE SALES',y= 'YEAR',s = 400,c = 'BLUE')
# Out:
# <Axes: xlabel='WAREHOUSE SALES', ylabel='YEAR'>
